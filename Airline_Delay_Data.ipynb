# %%
import pandas as pd

# %%
# Store filepath in a variable
data = "Resources/Airline_Delay_Cause.csv"

# %%
# Read Data file with the pandas library

data_df = pd.read_csv(data, encoding="ISO-8859-1")

# %%
# Preview the data within the Panda Dataframe

data_df.head()
# Out:
#    year  month carrier       carrier_name airport  \
# 0  2022      5      9E  Endeavor Air Inc.     ABE
# 1  2022      5      9E  Endeavor Air Inc.     ABY
# 2  2022      5      9E  Endeavor Air Inc.     ACK
# 3  2022      5      9E  Endeavor Air Inc.     AEX
# 4  2022      5      9E  Endeavor Air Inc.     AGS
#
#                                         airport_name  arr_flights  arr_del15  \
# 0  Allentown/Bethlehem/Easton, PA: Lehigh Valley ...        136.0        7.0
# 1             Albany, GA: Southwest Georgia Regional         91.0       16.0
# 2                  Nantucket, MA: Nantucket Memorial         19.0        2.0
# 3           Alexandria, LA: Alexandria International         88.0       14.0
# 4        Augusta, GA: Augusta Regional at Bush Field        181.0       19.0
#
#    carrier_ct  weather_ct  ...  security_ct  late_aircraft_ct  arr_cancelled  \
# 0        5.95        0.00  ...          0.0              1.00            0.0
# 1        7.38        0.00  ...          0.0              6.09            0.0
# 2        0.13        0.00  ...          0.0              0.88            1.0
# 3        7.26        0.76  ...          0.0              1.64            0.0
# 4       13.84        0.00  ...          0.0              2.09            0.0
#
#    arr_diverted  arr_delay  carrier_delay  weather_delay  nas_delay  \
# 0           0.0      255.0          222.0            0.0        4.0
# 1           0.0      884.0          351.0            0.0       81.0
# 2           0.0      138.0            4.0            0.0      106.0
# 3           0.0      947.0          585.0           35.0      125.0
# 4           0.0      808.0          662.0            0.0       87.0
#
#    security_delay  late_aircraft_delay
# 0             0.0                 29.0
# 1             0.0                452.0
# 2             0.0                 28.0
# 3             0.0                202.0
# 4             0.0                 59.0
#
# [5 rows x 21 columns]

# %%
# split() up the airport_name column to parse out City(s), State, and Airport name.  The State data will be used for the params in the API call. 

# new data frame with split value columns. Starting with the city name. 
new = data_df["airport_name"].str.split(",", n = 1, expand = True)
 
# making separate city column from new data frame
data_df["city"]= new[0]
 
# making separate column to parse out state from airport name
data_df["split1"]= new[1]

# Dropping old airport_name column
data_df.drop(columns =["airport_name"], inplace = True)

# %%
# Display updated dataframe with city name in it's own column. 
data_df.head(1)
# Out:
#    year  month carrier       carrier_name airport  arr_flights  arr_del15  \
# 0  2022      5      9E  Endeavor Air Inc.     ABE        136.0        7.0
#
#    carrier_ct  weather_ct  nas_ct  ...  arr_cancelled  arr_diverted  \
# 0        5.95         0.0    0.05  ...            0.0           0.0
#
#    arr_delay  carrier_delay  weather_delay  nas_delay  security_delay  \
# 0      255.0          222.0            0.0        4.0             0.0
#
#    late_aircraft_delay                        city  \
# 0                 29.0  Allentown/Bethlehem/Easton
#
#                              split1
# 0   PA: Lehigh Valley International
#
# [1 rows x 22 columns]

# %%
# using the same split() method, we're now splitting the state and airport name.
new1 = data_df["split1"].str.split(":", n = 1, expand = True)
 
# making separate city column from new data frame
data_df["state"]= new1[0]
 
# making separate column to parse out state from airport name
data_df["airport_name"]= new1[1]

# Dropping old airport_name column
data_df.drop(columns =["split1"], inplace = True)

# %%
#confirm that the old airport_name column with city, state, and airport name are now in their own columns (far right columns). 
data_df.head(1)
# Out:
#    year  month carrier       carrier_name airport  arr_flights  arr_del15  \
# 0  2022      5      9E  Endeavor Air Inc.     ABE        136.0        7.0
#
#    carrier_ct  weather_ct  nas_ct  ...  arr_diverted  arr_delay  \
# 0        5.95         0.0    0.05  ...           0.0      255.0
#
#    carrier_delay  weather_delay  nas_delay  security_delay  \
# 0          222.0            0.0        4.0             0.0
#
#    late_aircraft_delay                        city  state  \
# 0                 29.0  Allentown/Bethlehem/Easton     PA
#
#                    airport_name
# 0   Lehigh Valley International
#
# [1 rows x 23 columns]

# %%
#create a dataframe with only the airport information used for API calls.
# 1. remove any duplicates from the dataframe
# 2. Reset the index from the previous dataframe (otherwise, for example, the index number would range from 1 to 3k)
# 3. Pull only the columns we want from the previous dataframe. Airport Code, Airport Name. State. City. 
# 4. Rename columns to better describe the data

airport_df = data_df.drop_duplicates(["airport_name", "state", "city"]).reset_index(drop=True)[['airport', 'airport_name', 'state', 'city']]
airport_df = pd.DataFrame(airport_df.rename(columns={'airport':'airport_code'}))
airport_df
# Out:
#     airport_code                     airport_name state  \
# 0            ABE      Lehigh Valley International    PA
# 1            ABY       Southwest Georgia Regional    GA
# 2            ACK               Nantucket Memorial    MA
# 3            AEX         Alexandria International    LA
# 4            AGS   Augusta Regional at Bush Field    GA
# ..           ...                              ...   ...
# 415          MKK                          Molokai    HI
# 416          ILE                    Skylark Field    TX
# 417          SKA                    Fairchild AFB    WA
# 418          CBM                     Columbus AFB    MS
# 419          DUT                 Unalaska Airport    AK
#
#                            city
# 0    Allentown/Bethlehem/Easton
# 1                        Albany
# 2                     Nantucket
# 3                    Alexandria
# 4                       Augusta
# ..                          ...
# 415                    Hoolehua
# 416                     Killeen
# 417                     Spokane
# 418                    Columbus
# 419                    Unalaska
#
# [420 rows x 4 columns]

# %%
#create a dataframe for monthly data enteries of weather delays by carrier and airport.
# 1. Grab only the columns of data we need.
# 2. Rename columns to better describe the data

delay_data_df = data_df[['year', 'month', 'carrier', 'carrier_name', 'airport', 'airport_name', 'arr_flights', 'weather_delay']]
delay_data_df = pd.DataFrame(delay_data_df.rename(columns={'carrier':'carrier_code', 'airport':'airport_code', 'arr_flights':'arrival_flights'}))
delay_data_df
# Out:
#         year  month carrier_code          carrier_name airport_code  \
# 0       2022      5           9E     Endeavor Air Inc.          ABE
# 1       2022      5           9E     Endeavor Air Inc.          ABY
# 2       2022      5           9E     Endeavor Air Inc.          ACK
# 3       2022      5           9E     Endeavor Air Inc.          AEX
# 4       2022      5           9E     Endeavor Air Inc.          AGS
# ...      ...    ...          ...                   ...          ...
# 318012  2003      6           DL  Delta Air Lines Inc.          SEA
# 318013  2003      6           DL  Delta Air Lines Inc.          SFO
# 318014  2003      6           DL  Delta Air Lines Inc.          SJC
# 318015  2003      6           DL  Delta Air Lines Inc.          SJU
# 318016  2003      6           DL  Delta Air Lines Inc.          SLC
#
#                                     airport_name  arrival_flights  \
# 0                    Lehigh Valley International            136.0
# 1                     Southwest Georgia Regional             91.0
# 2                             Nantucket Memorial             19.0
# 3                       Alexandria International             88.0
# 4                 Augusta Regional at Bush Field            181.0
# ...                                          ...              ...
# 318012              Seattle/Tacoma International            480.0
# 318013               San Francisco International            505.0
# 318014   Norman Y. Mineta San Jose International            146.0
# 318015            Luis Munoz Marin International             95.0
# 318016              Salt Lake City International           3466.0
#
#         weather_delay
# 0                 0.0
# 1                 0.0
# 2                 0.0
# 3                35.0
# 4                 0.0
# ...               ...
# 318012          164.0
# 318013          138.0
# 318014            0.0
# 318015            0.0
# 318016          306.0
#
# [318017 rows x 8 columns]

# %%
#create database for carrier name and code 
carrier_df = data_df.drop_duplicates(["carrier_name", "carrier"]).reset_index(drop=True)[["carrier_name", "carrier"]]
carrier_df = pd.DataFrame(carrier_df.rename(columns={'carrier':'carrier_code'}))
carrier_df
# Out:
#                     carrier_name carrier_code
# 0              Endeavor Air Inc.           9E
# 1         American Airlines Inc.           AA
# 2           Alaska Airlines Inc.           AS
# 3                JetBlue Airways           B6
# 4           Delta Air Lines Inc.           DL
# 5         Frontier Airlines Inc.           F9
# 6                  Allegiant Air           G4
# 7         Hawaiian Airlines Inc.           HA
# 8                      Envoy Air           MQ
# 9               Spirit Air Lines           NK
# 10             PSA Airlines Inc.           OH
# 11         SkyWest Airlines Inc.           OO
# 12                   Horizon Air           QX
# 13         United Air Lines Inc.           UA
# 14        Southwest Airlines Co.           WN
# 15            Mesa Airlines Inc.           YV
# 16              Republic Airline           YX
# 17       ExpressJet Airlines LLC           EV
# 18      ExpressJet Airlines Inc.           EV
# 19                Virgin America           VX
# 20               US Airways Inc.           US
# 21   AirTran Airways Corporation           FL
# 22  American Eagle Airlines Inc.           MQ
# 23        Pinnacle Airlines Inc.           9E
# 24   Atlantic Southeast Airlines           EV
# 25      ExpressJet Airlines Inc.           XE
# 26    Continental Air Lines Inc.           CO
# 27                   Comair Inc.           OH
# 28       Northwest Airlines Inc.           NW
# 29           Aloha Airlines Inc.           AQ
# 30        ATA Airlines d/b/a ATA           TZ
# 31      ExpressJet Airlines Inc.           RU
# 32              Independence Air           DH
# 33    America West Airlines Inc.           HP
# 34       Atlantic Coast Airlines           DH

# %%
state_df = data_df.drop_duplicates(["state"]).reset_index(drop=True)[["state"]].reset_index()
state_df.rename(columns={'index':'state_id'})
# Out:
#     state_id state
# 0          0    PA
# 1          1    GA
# 2          2    MA
# 3          3    LA
# 4          4    NY
# 5          5    WI
# 6          6    TX
# 7          7    NC
# 8          8    MI
# 9          9    ME
# 10        10    AL
# 11        11    IL
# 12        12    TN
# 13        13    VT
# 14        14    MD
# 15        15    SC
# 16        16    VA
# 17        17    IA
# 18        18    OH
# 19        19    WV
# 20        20    DC
# 21        21    MN
# 22        22    IN
# 23        23    NJ
# 24        24    FL
# 25        25    SD
# 26        26    MS
# 27        27    KY
# 28        28    MO
# 29        29    ND
# 30        30    NE
# 31        31    RI
# 32        32    AR
# 33        33    NM
# 34        34    AK
# 35        35    CT
# 36        36    ID
# 37        37    CA
# 38        38    MT
# 39        39    CO
# 40        40    OR
# 41        41    WA
# 42        42    HI
# 43        43    KS
# 44        44    NV
# 45        45    OK
# 46        46    AZ
# 47        47    PR
# 48        48    UT
# 49        49    VI
# 50        50    DE
# 51        51    NH
# 52        52    TT
# 53        53    WY

# %%
#export csv file 
airport_df.to_csv('Resources/airport_df.csv', index=False)

# %%
#export csv file 
delay_data_df.to_csv('Resources/delay_data_df.csv', index=False)

# %%
#export csv file 
carrier_df.to_csv('Resources/carrier_df.csv', index=False)

# %%
#export csv file 
state_df.to_csv('Resources/state_df.csv', index=False)
